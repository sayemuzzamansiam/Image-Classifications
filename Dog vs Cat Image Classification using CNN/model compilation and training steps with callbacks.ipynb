# %% [markdown]
# # Cat vs Dog Image Classification (CNN)

# %% [markdown]
# ## A general CNN architecture

# %% [markdown]
# ![CNN architecture](https://miro.medium.com/v2/resize:fit:1400/1*d_xC3OqjOCYQtMfLawxzgg.png)

# %%
"""Importing Imp Libraries"""
import os
from PIL import Image
import random

import numpy as np
import tensorflow as tf


from tensorflow import keras
from keras import Sequential 
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %% [markdown]
# ## Keras's Sequential Class:
# The Sequential class in Keras is used to create a neural network where each layer has exactly one input and one output. Layers in a Sequential model are arranged in a linear stack, and you can add one layer at a time using the .add() method.

# %% [markdown]
# # Read The Data

# %% [markdown]
# ## The very first thing we will do is load/read this dataset, and then get some additional information about the dataset before displaying the Image data.
#
# ### We will read the data in 3 different way

# %%
# define the dir path of train and test

train_dir= "/kaggle/input/dogs-vs-cats/train"
test_dir = "/kaggle/input/dogs-vs-cats/test"

# %%
# let's check the train dir
x = os.listdir(train_dir)
print("Inside the train dir: ", x)


# now we will find out the num of data inside each of the dog and cat folder

#dogs fol
dogs = len(os.listdir(os.path.join(train_dir, "dogs")))
print("num of dog images in train_dir's dogs fol: ", dogs)

#cats fol
cats = len(os.listdir(os.path.join(train_dir, "cats")))
print("num of cat images in train_dir's cats fol: ", cats)
# Out:
# Inside the train dir:  ['dogs', 'cats']
# num of dog images in train_dir's dogs fol:  10000
# num of cat images in train_dir's cats fol:  10000

# %% [markdown]
# ### Using indexing-slicling

# %%
# let see what in inside the dogs and the cats dir
dog_data = os.listdir(os.path.join(train_dir,"dogs")) 
cat_data = os.listdir(os.path.join(train_dir, "cats"))


# let's slice it
n = 5
sample_dog_data = dog_data[:n]
sample_cat_data = cat_data[:n]

#now it's time to print
print("this is dog what inside the dog_data: ",sample_dog_data)
print("this is dog what inside the dog_data: ",sample_cat_data)
# Out:
# this is dog what inside the dog_data:  ['dog.3443.jpg', 'dog.7971.jpg', 'dog.10728.jpg', 'dog.1942.jpg', 'dog.3259.jpg']
# this is dog what inside the dog_data:  ['cat.12461.jpg', 'cat.10176.jpg', 'cat.8194.jpg', 'cat.3498.jpg', 'cat.891.jpg']

# %% [markdown]
# ### Using Enumerate() function

# %%
# Now let's use enumerate()

dog_data 
cat_data 
n = 5

for i,v in enumerate(dog_data[:n]):
    print("Inside Dog dir: ", v)

print('\n')

for i, f in enumerate (cat_data[:n]):
    print("Inside Cat dir: ",f)
# Out:
# Inside Dog dir:  dog.3443.jpg
# Inside Dog dir:  dog.7971.jpg
# Inside Dog dir:  dog.10728.jpg
# Inside Dog dir:  dog.1942.jpg
# Inside Dog dir:  dog.3259.jpg
#
#
# Inside Cat dir:  cat.12461.jpg
# Inside Cat dir:  cat.10176.jpg
# Inside Cat dir:  cat.8194.jpg
# Inside Cat dir:  cat.3498.jpg
# Inside Cat dir:  cat.891.jpg

# %% [markdown]
# ### Using range() function:

# %%
# now let's use range() to read the data

n =5
for j in range(len(dog_data[:n])):
    print(dog_data[j])

print('\n')
for i in range(len(cat_data[:n])):
    print(cat_data[i])
# Out:
# dog.3443.jpg
# dog.7971.jpg
# dog.10728.jpg
# dog.1942.jpg
# dog.3259.jpg
#
#
# cat.12461.jpg
# cat.10176.jpg
# cat.8194.jpg
# cat.3498.jpg
# cat.891.jpg

# %% [markdown]
# # Display The Image Data

# %%
"""Display Some Image Data"""

dog_data = os.listdir(os.path.join(train_dir,"dogs")) 
cat_data = os.listdir(os.path.join(train_dir, "cats"))

def display_images(dog,cat,num_of_images=5):

    # here we are randomly selecting few images
    dog_image = random.sample(dog,num_of_images)
    cat_image = random.sample(cat,num_of_images)

    plt.figure(figsize=(12,4)) # creating dims for our figure. weidth=10 and height = 5

    
    for i in range(num_of_images):

        #for the dog
        plt.subplot(2,num_of_images,i+1) # we are creating subplot inside the figure. nrows,ncols,num_of_current_img
        img = Image.open(os.path.join(train_dir,"dogs", dog_image[i])) # storing the image inside img, by constructing the path
        plt.imshow(img)
        plt.title("dog")
        plt.axis('off')


        # for the cat
        plt.subplot(2,num_of_images,i+num_of_images+1)
        img = Image.open(os.path.join(train_dir,"cats", cat_image[i]))
        plt.imshow(img)
        plt.title("cat")
        plt.axis("off")

    plt.tight_layout() ## To make sure the subplots don't overlap
    plt.show()

display_images(dog_data,cat_data)

# %% [markdown]
# # Prepare data using keras directory-based system

# %%
"""Let's create a generator/Data Loder"""
# for train
train_data = keras.utils.image_dataset_from_directory(
    directory = "/kaggle/input/dogs-vs-cats/train",
    labels = "inferred",  # automatically infer the labels based on folders
    label_mode = 'int', # we want the labels in int 
    subset = 'training',
    validation_split = 0.2,
    batch_size = 32,
    image_size = (256, 256),
    seed = 123
    
)

# for validation
val_data = keras.utils.image_dataset_from_directory(
    directory = "/kaggle/input/dogs-vs-cats/train",
    labels = "inferred",
    label_mode = 'int',
    validation_split = 0.2,
    subset = 'validation',
    batch_size = 32,
    image_size = (256, 256),
    seed =123
)
# Out:
# Found 20000 files belonging to 2 classes.
# Using 16000 files for training.
# Found 20000 files belonging to 2 classes.
# Using 4000 files for validation.

# %%
# Get a batch of images and labels from the training data
image_batch, label_batch = next(iter(train_data))


plt.figure(figsize=(15, 10))

for i in range(4):
    plt.subplot(1, 4, i + 1)  # Create a subplot for each image
    plt.imshow(image_batch[i].numpy().astype("uint8"))  # Convert the tensor to a numpy array and display the image
    plt.title('Cat' if label_batch[i].numpy() == 0 else 'Dog')
    plt.axis('off') 

plt.show()

# %%
image_batch.shape
# Out:
# TensorShape([32, 256, 256, 3])

# %%
label_batch.shape
# Out:
# TensorShape([32])

# %%
"""Preprocessing"""
# applying normalization

def norm(image, label):
    image = tf.cast(image/255. , tf.float32) # normalize the pixel values to the range of [0.0, 1.0]
    return image,label

# applying norm on the dataset
train_data = train_data.map(norm)
val_data = val_data.map(norm)

# %% [markdown]
# ## Model Architecture

# %%
from keras.layers import Dropout

# creating the model architecture

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding ='valid', activation='relu', input_shape=(256,256,3)))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size =(2,2), strides=2,padding='valid'))


 
model.add(Conv2D(64,kernel_size=(3,3),padding ='valid',activation='relu'))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size =(2,2), strides=2,padding='valid'))


model.add(Conv2D(128,kernel_size=(3,3),padding ='valid',activation='relu'))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size =(2,2), strides=2,padding='valid'))


model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))

# Output layer
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 254, 254, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 125, 125, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 125, 125, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 60, 60, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 60, 60, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 30, 30, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 115200)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │      14,745,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,848,193 (56.64 MB)
#  Trainable params: 14,847,745 (56.64 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
plot_model(model, show_shapes = True, dpi =50)

# %%
"""Now let's compile the model"""

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
"""Let us define check-point and early stopping"""
from keras.callbacks import ModelCheckpoint, EarlyStopping

# this will save the best model
checkpoint = ModelCheckpoint(

    'best_model.keras',
    monitor = 'val_accuracy',
    save_best_only = True,
    mode = max,
    verbose = 1
)


earlystop = EarlyStopping(

    monitor = 'val_accuracy',
    patience = 5,
    restore_best_weights = True,
    verbose = 1
)
# Out:
# <ipython-input-55-41dc651b0164>:5: UserWarning: ModelCheckpoint mode '<built-in function max>' is unknown, fallback to auto mode.
#   checkpoint = ModelCheckpoint(

# %%
history = model.fit(train_data,epochs=25, validation_data=val_data,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5271 - loss: 3.3598
# Epoch 1: val_accuracy improved from -inf to 0.50825, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 48s 86ms/step - accuracy: 0.5271 - loss: 3.3564 - val_accuracy: 0.5082 - val_loss: 0.8249
# Epoch 2/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5657 - loss: 0.6719
# Epoch 2: val_accuracy improved from 0.50825 to 0.62825, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 73ms/step - accuracy: 0.5657 - loss: 0.6719 - val_accuracy: 0.6283 - val_loss: 0.6355
# Epoch 3/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6007 - loss: 0.6439
# Epoch 3: val_accuracy did not improve from 0.62825
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 73ms/step - accuracy: 0.6007 - loss: 0.6439 - val_accuracy: 0.5502 - val_loss: 0.6768
# Epoch 4/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6037 - loss: 0.6498
# Epoch 4: val_accuracy did not improve from 0.62825
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6037 - loss: 0.6498 - val_accuracy: 0.6053 - val_loss: 0.6477
# Epoch 5/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6126 - loss: 0.6294
# Epoch 5: val_accuracy improved from 0.62825 to 0.69925, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - accuracy: 0.6126 - loss: 0.6294 - val_accuracy: 0.6992 - val_loss: 0.5952
# Epoch 6/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6020 - loss: 0.6362
# Epoch 6: val_accuracy improved from 0.69925 to 0.71025, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 75ms/step - accuracy: 0.6020 - loss: 0.6362 - val_accuracy: 0.7103 - val_loss: 0.5613
# Epoch 7/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6474 - loss: 0.5999
# Epoch 7: val_accuracy improved from 0.71025 to 0.72225, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 75ms/step - accuracy: 0.6474 - loss: 0.5999 - val_accuracy: 0.7222 - val_loss: 0.5411
# Epoch 8/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6435 - loss: 0.5935
# Epoch 8: val_accuracy did not improve from 0.72225
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.6435 - loss: 0.5936 - val_accuracy: 0.7092 - val_loss: 0.5611
# Epoch 9/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6246 - loss: 0.5940
# Epoch 9: val_accuracy did not improve from 0.72225
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 73ms/step - accuracy: 0.6246 - loss: 0.5940 - val_accuracy: 0.6640 - val_loss: 0.5846
# Epoch 10/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6644 - loss: 0.5661
# Epoch 10: val_accuracy did not improve from 0.72225
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6644 - loss: 0.5661 - val_accuracy: 0.7023 - val_loss: 0.5436
# Epoch 11/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6891 - loss: 0.5436
# Epoch 11: val_accuracy did not improve from 0.72225
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.6891 - loss: 0.5436 - val_accuracy: 0.6848 - val_loss: 0.5915
# Epoch 12/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6931 - loss: 0.5408
# Epoch 12: val_accuracy improved from 0.72225 to 0.77000, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.6931 - loss: 0.5407 - val_accuracy: 0.7700 - val_loss: 0.5184
# Epoch 13/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6979 - loss: 0.5415
# Epoch 13: val_accuracy did not improve from 0.77000
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6980 - loss: 0.5414 - val_accuracy: 0.7370 - val_loss: 0.5051
# Epoch 14/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7048 - loss: 0.5199
# Epoch 14: val_accuracy improved from 0.77000 to 0.78900, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.7049 - loss: 0.5199 - val_accuracy: 0.7890 - val_loss: 0.4570
# Epoch 15/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7334 - loss: 0.4899
# Epoch 15: val_accuracy did not improve from 0.78900
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.7334 - loss: 0.4899 - val_accuracy: 0.7885 - val_loss: 0.4495
# Epoch 16/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7422 - loss: 0.4669
# Epoch 16: val_accuracy did not improve from 0.78900
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7422 - loss: 0.4669 - val_accuracy: 0.7885 - val_loss: 0.4553
# Epoch 17/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7416 - loss: 0.4653
# Epoch 17: val_accuracy did not improve from 0.78900
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7416 - loss: 0.4653 - val_accuracy: 0.7700 - val_loss: 0.4578
# Epoch 18/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7490 - loss: 0.4598
# Epoch 18: val_accuracy did not improve from 0.78900
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.7490 - loss: 0.4598 - val_accuracy: 0.7433 - val_loss: 0.6155
# Epoch 19/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7618 - loss: 0.4298
# Epoch 19: val_accuracy improved from 0.78900 to 0.79900, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.7618 - loss: 0.4298 - val_accuracy: 0.7990 - val_loss: 0.4337
# Epoch 20/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7671 - loss: 0.4163
# Epoch 20: val_accuracy did not improve from 0.79900
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7671 - loss: 0.4163 - val_accuracy: 0.6217 - val_loss: 0.5877
# Epoch 21/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7725 - loss: 0.4103
# Epoch 21: val_accuracy improved from 0.79900 to 0.81025, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.7725 - loss: 0.4102 - val_accuracy: 0.8102 - val_loss: 0.4400
# Epoch 22/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7954 - loss: 0.3868
# Epoch 22: val_accuracy improved from 0.81025 to 0.81425, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.7954 - loss: 0.3868 - val_accuracy: 0.8142 - val_loss: 0.4267
# Epoch 23/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7911 - loss: 0.3850
# Epoch 23: val_accuracy did not improve from 0.81425
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7911 - loss: 0.3850 - val_accuracy: 0.7875 - val_loss: 0.5435
# Epoch 24/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7923 - loss: 0.3730
# Epoch 24: val_accuracy did not improve from 0.81425
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7923 - loss: 0.3730 - val_accuracy: 0.8140 - val_loss: 0.4301
# Epoch 25/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8006 - loss: 0.3673
# Epoch 25: val_accuracy did not improve from 0.81425
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.8006 - loss: 0.3673 - val_accuracy: 0.8037 - val_loss: 0.5472
# Restoring model weights from the end of the best epoch: 22.

# %%
"""from the info we can already see that the model is overfitted but let's go and plot it"""

plt.plot(history.history['accuracy'], label= 'Train Accuracy',color ='green')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.legend()

# %%
plt.plot(history.history['loss'],label ='train loss')
plt.plot(history.history['val_loss'],label= 'validation loss')
