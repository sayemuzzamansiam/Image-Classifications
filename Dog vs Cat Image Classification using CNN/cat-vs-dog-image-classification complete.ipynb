# %% [markdown]
# # Cat vs Dog Image Classification (CNN)

# %% [markdown]
# ## A general CNN architecture

# %% [markdown]
# ![CNN architecture](https://miro.medium.com/v2/resize:fit:1400/1*d_xC3OqjOCYQtMfLawxzgg.png)

# %%
"""Importing Imp Libraries"""
import os
from PIL import Image
import random

import numpy as np
import tensorflow as tf


from tensorflow import keras
from keras import Sequential 
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %% [markdown]
# ## Keras's Sequential Class:
# The Sequential class in Keras is used to create a neural network where each layer has exactly one input and one output. Layers in a Sequential model are arranged in a linear stack, and you can add one layer at a time using the .add() method.

# %% [markdown]
# # Read The Data

# %% [markdown]
# ## The very first thing we will do is load/read this dataset, and then get some additional information about the dataset before displaying the Image data.
#
# ### We will read the data in 3 different way

# %%
# define the dir path of train and test

train_dir= "/kaggle/input/dogs-vs-cats/train"
test_dir = "/kaggle/input/dogs-vs-cats/test"

# %%
# let's check the train dir
x = os.listdir(train_dir)
print("Inside the train dir: ", x)


# now we will find out the num of data inside each of the dog and cat folder

#dogs fol
dogs = len(os.listdir(os.path.join(train_dir, "dogs")))
print("num of dog images in train_dir's dogs fol: ", dogs)

#cats fol
cats = len(os.listdir(os.path.join(train_dir, "cats")))
print("num of cat images in train_dir's cats fol: ", cats)
# Out:
# Inside the train dir:  ['dogs', 'cats']
# num of dog images in train_dir's dogs fol:  10000
# num of cat images in train_dir's cats fol:  10000

# %% [markdown]
# ### Using indexing-slicling

# %%
# let see what in inside the dogs and the cats dir
dog_data = os.listdir(os.path.join(train_dir,"dogs")) 
cat_data = os.listdir(os.path.join(train_dir, "cats"))


# let's slice it
n = 5
sample_dog_data = dog_data[:n]
sample_cat_data = cat_data[:n]

#now it's time to print
print("this is dog what inside the dog_data: ",sample_dog_data)
print("this is dog what inside the dog_data: ",sample_cat_data)
# Out:
# this is dog what inside the dog_data:  ['dog.3443.jpg', 'dog.7971.jpg', 'dog.10728.jpg', 'dog.1942.jpg', 'dog.3259.jpg']
# this is dog what inside the dog_data:  ['cat.12461.jpg', 'cat.10176.jpg', 'cat.8194.jpg', 'cat.3498.jpg', 'cat.891.jpg']

# %% [markdown]
# ### Using Enumerate() function

# %%
# Now let's use enumerate()

dog_data 
cat_data 
n = 5

for i,v in enumerate(dog_data[:n]):
    print("Inside Dog dir: ", v)

print('\n')

for i, f in enumerate (cat_data[:n]):
    print("Inside Cat dir: ",f)
# Out:
# Inside Dog dir:  dog.3443.jpg
# Inside Dog dir:  dog.7971.jpg
# Inside Dog dir:  dog.10728.jpg
# Inside Dog dir:  dog.1942.jpg
# Inside Dog dir:  dog.3259.jpg
#
#
# Inside Cat dir:  cat.12461.jpg
# Inside Cat dir:  cat.10176.jpg
# Inside Cat dir:  cat.8194.jpg
# Inside Cat dir:  cat.3498.jpg
# Inside Cat dir:  cat.891.jpg

# %% [markdown]
# ### Using range() function:

# %%
# now let's use range() to read the data

n =5
for j in range(len(dog_data[:n])):
    print(dog_data[j])

print('\n')
for i in range(len(cat_data[:n])):
    print(cat_data[i])
# Out:
# dog.3443.jpg
# dog.7971.jpg
# dog.10728.jpg
# dog.1942.jpg
# dog.3259.jpg
#
#
# cat.12461.jpg
# cat.10176.jpg
# cat.8194.jpg
# cat.3498.jpg
# cat.891.jpg

# %% [markdown]
# # Display The Image Data

# %%
"""Display Some Image Data"""

dog_data = os.listdir(os.path.join(train_dir,"dogs")) 
cat_data = os.listdir(os.path.join(train_dir, "cats"))

def display_images(dog,cat,num_of_images=5):

    # here we are randomly selecting few images
    dog_image = random.sample(dog,num_of_images)
    cat_image = random.sample(cat,num_of_images)

    plt.figure(figsize=(12,4)) # creating dims for our figure. weidth=10 and height = 5

    
    for i in range(num_of_images):

        #for the dog
        plt.subplot(2,num_of_images,i+1) # we are creating subplot inside the figure. nrows,ncols,num_of_current_img
        img = Image.open(os.path.join(train_dir,"dogs", dog_image[i])) # storing the image inside img, by constructing the path
        plt.imshow(img)
        plt.title("dog")
        plt.axis('off')


        # for the cat
        plt.subplot(2,num_of_images,i+num_of_images+1)
        img = Image.open(os.path.join(train_dir,"cats", cat_image[i]))
        plt.imshow(img)
        plt.title("cat")
        plt.axis("off")

    plt.tight_layout() ## To make sure the subplots don't overlap
    plt.show()

display_images(dog_data,cat_data)

# %% [markdown]
# # Prepare data using keras directory-based system

# %%
"""Let's create a generator/Data Loder"""
# for train
train_data = keras.utils.image_dataset_from_directory(
    directory = "/kaggle/input/dogs-vs-cats/train",
    labels = "inferred",  # automatically infer the labels based on folders
    label_mode = 'int', # we want the labels in int 
    subset = 'training',
    validation_split = 0.2,
    batch_size = 32,
    image_size = (256, 256),
    seed = 123
    
)

# for validation
val_data = keras.utils.image_dataset_from_directory(
    directory = "/kaggle/input/dogs-vs-cats/train",
    labels = "inferred",
    label_mode = 'int',
    validation_split = 0.2,
    subset = 'validation',
    batch_size = 32,
    image_size = (256, 256),
    seed =123
)
# Out:
# Found 20000 files belonging to 2 classes.
# Using 16000 files for training.
# Found 20000 files belonging to 2 classes.
# Using 4000 files for validation.

# %%
# Get a batch of images and labels from the training data
image_batch, label_batch = next(iter(train_data))


plt.figure(figsize=(15, 10))

for i in range(4):
    plt.subplot(1, 4, i + 1)  # Create a subplot for each image
    plt.imshow(image_batch[i].numpy().astype("uint8"))  # Convert the tensor to a numpy array and display the image
    plt.title('Cat' if label_batch[i].numpy() == 0 else 'Dog')
    plt.axis('off') 

plt.show()

# %%
image_batch.shape
# Out:
# TensorShape([32, 256, 256, 3])

# %%
label_batch.shape
# Out:
# TensorShape([32])

# %%
"""Preprocessing"""
# applying normalization

def norm(image, label):
    image = tf.cast(image/255. , tf.float32) # normalize the pixel values to the range of [0.0, 1.0]
    return image,label

# applying norm on the dataset
train_data = train_data.map(norm)
val_data = val_data.map(norm)

# %% [markdown]
# ## Model Architecture

# %%
from keras.layers import Dropout

# creating the model architecture

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding ='valid', activation='relu', input_shape=(256,256,3)))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size =(2,2), strides=2,padding='valid'))


 
model.add(Conv2D(64,kernel_size=(3,3),padding ='valid',activation='relu'))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size =(2,2), strides=2,padding='valid'))


model.add(Conv2D(128,kernel_size=(3,3),padding ='valid',activation='relu'))
model.add(BatchNormalization())  
model.add(MaxPooling2D(pool_size =(2,2), strides=2,padding='valid'))


model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))

# Output layer
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 254, 254, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 125, 125, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 60, 60, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 115200)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      14,745,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,848,193 (56.64 MB)
#  Trainable params: 14,847,745 (56.64 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
plot_model(model, show_shapes = True, dpi =50)

# %%
"""Now let's compile the model"""

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
"""Let us define check-point and early stopping"""
from keras.callbacks import ModelCheckpoint, EarlyStopping

# this will save the best model
checkpoint = ModelCheckpoint(

    'best_model.keras',
    monitor = 'val_accuracy',
    save_best_only = True,
    mode = max,
    verbose = 1
)


earlystop = EarlyStopping(

    monitor = 'val_accuracy',
    patience = 5,
    restore_best_weights = True,
    verbose = 1
)
# Out:
# <ipython-input-17-41dc651b0164>:5: UserWarning: ModelCheckpoint mode '<built-in function max>' is unknown, fallback to auto mode.
#   checkpoint = ModelCheckpoint(

# %%
history = model.fit(train_data,epochs=30, validation_data=val_data,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5292 - loss: 4.4000
# Epoch 1: val_accuracy improved from -inf to 0.54725, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.5292 - loss: 4.3957 - val_accuracy: 0.5472 - val_loss: 0.7137
# Epoch 2/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5461 - loss: 0.6945
# Epoch 2: val_accuracy improved from 0.54725 to 0.54925, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.5461 - loss: 0.6945 - val_accuracy: 0.5493 - val_loss: 0.6761
# Epoch 3/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5708 - loss: 0.6750
# Epoch 3: val_accuracy improved from 0.54925 to 0.62350, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.5708 - loss: 0.6750 - val_accuracy: 0.6235 - val_loss: 0.6423
# Epoch 4/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6007 - loss: 0.6716
# Epoch 4: val_accuracy did not improve from 0.62350
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6006 - loss: 0.6716 - val_accuracy: 0.5385 - val_loss: 0.6958
# Epoch 5/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6055 - loss: 0.6531
# Epoch 5: val_accuracy did not improve from 0.62350
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 71ms/step - accuracy: 0.6055 - loss: 0.6531 - val_accuracy: 0.6035 - val_loss: 0.6559
# Epoch 6/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6246 - loss: 0.6449
# Epoch 6: val_accuracy did not improve from 0.62350
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6245 - loss: 0.6449 - val_accuracy: 0.6062 - val_loss: 0.6602
# Epoch 7/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6050 - loss: 0.6557
# Epoch 7: val_accuracy improved from 0.62350 to 0.63600, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.6051 - loss: 0.6557 - val_accuracy: 0.6360 - val_loss: 0.6347
# Epoch 8/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6262 - loss: 0.6373
# Epoch 8: val_accuracy improved from 0.63600 to 0.67600, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.6262 - loss: 0.6373 - val_accuracy: 0.6760 - val_loss: 0.6128
# Epoch 9/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6370 - loss: 0.6324
# Epoch 9: val_accuracy did not improve from 0.67600
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6370 - loss: 0.6324 - val_accuracy: 0.6595 - val_loss: 0.6306
# Epoch 10/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6475 - loss: 0.6279
# Epoch 10: val_accuracy improved from 0.67600 to 0.68825, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.6475 - loss: 0.6279 - val_accuracy: 0.6883 - val_loss: 0.5956
# Epoch 11/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6521 - loss: 0.6165
# Epoch 11: val_accuracy improved from 0.68825 to 0.69575, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.6522 - loss: 0.6165 - val_accuracy: 0.6957 - val_loss: 0.5996
# Epoch 12/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6706 - loss: 0.6063
# Epoch 12: val_accuracy improved from 0.69575 to 0.71500, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 75ms/step - accuracy: 0.6707 - loss: 0.6063 - val_accuracy: 0.7150 - val_loss: 0.5699
# Epoch 13/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6968 - loss: 0.5849
# Epoch 13: val_accuracy did not improve from 0.71500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6968 - loss: 0.5849 - val_accuracy: 0.6580 - val_loss: 0.6755
# Epoch 14/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6883 - loss: 0.5856
# Epoch 14: val_accuracy did not improve from 0.71500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6883 - loss: 0.5856 - val_accuracy: 0.7113 - val_loss: 0.5712
# Epoch 15/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7129 - loss: 0.5596
# Epoch 15: val_accuracy did not improve from 0.71500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7129 - loss: 0.5596 - val_accuracy: 0.6810 - val_loss: 0.6072
# Epoch 16/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7109 - loss: 0.5687
# Epoch 16: val_accuracy did not improve from 0.71500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7109 - loss: 0.5687 - val_accuracy: 0.6737 - val_loss: 0.6375
# Epoch 17/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7231 - loss: 0.5511
# Epoch 17: val_accuracy improved from 0.71500 to 0.75500, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.7232 - loss: 0.5511 - val_accuracy: 0.7550 - val_loss: 0.5272
# Epoch 18/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7339 - loss: 0.5358
# Epoch 18: val_accuracy did not improve from 0.75500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7339 - loss: 0.5358 - val_accuracy: 0.7090 - val_loss: 0.5684
# Epoch 19/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7419 - loss: 0.5264
# Epoch 19: val_accuracy did not improve from 0.75500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 73ms/step - accuracy: 0.7419 - loss: 0.5264 - val_accuracy: 0.7525 - val_loss: 0.5336
# Epoch 20/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7529 - loss: 0.5088
# Epoch 20: val_accuracy did not improve from 0.75500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7529 - loss: 0.5088 - val_accuracy: 0.6445 - val_loss: 0.6440
# Epoch 21/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7370 - loss: 0.5365
# Epoch 21: val_accuracy did not improve from 0.75500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.7370 - loss: 0.5365 - val_accuracy: 0.7450 - val_loss: 0.5279
# Epoch 22/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7648 - loss: 0.4999
# Epoch 22: val_accuracy improved from 0.75500 to 0.76675, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.7648 - loss: 0.4999 - val_accuracy: 0.7667 - val_loss: 0.5155
# Epoch 23/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7748 - loss: 0.4823
# Epoch 23: val_accuracy did not improve from 0.76675
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.7748 - loss: 0.4823 - val_accuracy: 0.7075 - val_loss: 0.5757
# Epoch 24/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7787 - loss: 0.4778
# Epoch 24: val_accuracy improved from 0.76675 to 0.78050, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.7787 - loss: 0.4778 - val_accuracy: 0.7805 - val_loss: 0.4813
# Epoch 25/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7847 - loss: 0.4663
# Epoch 25: val_accuracy improved from 0.78050 to 0.78275, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 75ms/step - accuracy: 0.7847 - loss: 0.4663 - val_accuracy: 0.7828 - val_loss: 0.4832
# Epoch 26/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7970 - loss: 0.4432
# Epoch 26: val_accuracy did not improve from 0.78275
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.7970 - loss: 0.4432 - val_accuracy: 0.7362 - val_loss: 0.5337
# Epoch 27/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7974 - loss: 0.4439
# Epoch 27: val_accuracy did not improve from 0.78275
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.7974 - loss: 0.4439 - val_accuracy: 0.7588 - val_loss: 0.5118
# Epoch 28/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8128 - loss: 0.4205
# Epoch 28: val_accuracy improved from 0.78275 to 0.79900, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.8129 - loss: 0.4205 - val_accuracy: 0.7990 - val_loss: 0.4569
# Epoch 29/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8218 - loss: 0.4081
# Epoch 29: val_accuracy did not improve from 0.79900
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.8218 - loss: 0.4081 - val_accuracy: 0.7713 - val_loss: 0.4950
# Epoch 30/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8188 - loss: 0.4181
# Epoch 30: val_accuracy improved from 0.79900 to 0.81150, saving model to best_model.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.8189 - loss: 0.4181 - val_accuracy: 0.8115 - val_loss: 0.4479
# Restoring model weights from the end of the best epoch: 30.

# %%
"""from the info we can already see that the model is overfitted but let's go and plot it"""

plt.plot(history.history['accuracy'], label= 'Train Accuracy',color ='green')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.legend()

# %%
plt.plot(history.history['loss'],label ='train loss')
plt.plot(history.history['val_loss'],label= 'validation loss')

# %% [markdown]
# # Model Evalueation

# %%
test_data = keras.utils.image_dataset_from_directory(
    directory = test_dir,
    labels = 'inferred',
    label_mode = 'int',
    batch_size = 32,
    image_size = (256, 256),
    seed = 123
)

# Apply normalization
test_data = test_data.map(norm)
# Out:
# Found 5000 files belonging to 2 classes.

# %%
test_loss, test_accuracy = model.evaluate(test_data)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.8098 - loss: 0.4474
# Test Loss: 0.4472734034061432
# Test Accuracy: 0.8086000084877014

# %% [markdown]
# # Model Predictions

# %%
# Get the model's predictions on the test data
predictions = model.predict(test_data)
predicted_labels = np.where(predictions > 0.5, 1, 0)  

# Get true labels
true_labels = np.concatenate([y for x, y in test_data], axis=0)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step

# %%
test_dir = '/kaggle/input/dogs-vs-cats/test'

dog_folder = os.path.join(test_dir, 'dogs')
cat_folder = os.path.join(test_dir, 'cats')

dog_data = os.listdir(dog_folder)
cat_data = os.listdir(cat_folder)


plt.figure(figsize=(12, 4))
for i in range(5): 
    plt.subplot(1, 5, i + 1)
    
    # display prediction (dog if predicted 1, cat if predicted 0)
    img_path = os.path.join(dog_folder, dog_data[i]) if predicted_labels[i][0] == 1 else os.path.join(cat_folder, cat_data[i])
    img = Image.open(img_path)
    
    # display the images with predicted label
    plt.imshow(img)
    plt.title('Predicted: ' + ('Dog' if predicted_labels[i][0] == 1 else 'Cat'))
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# Load the saved model
best_model = load_model('best_model.keras')
