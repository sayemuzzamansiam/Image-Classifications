# %% [markdown]
# # Model Prediction

# %%
"""Visualize the prediction"""

sample_images, sample_labels = next(iter(test_data))
predictions = model.predict(sample_images)
predicted_labels = (predictions>0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
plt.figure(figsize = (15,7))

for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow((sample_images[i].numpy()+1) /2) #undo norm
    plt.title(f"Pred: {'Dog' if predicted_labels[i] else 'Cat'}\nTrue: {'Dog' if sample_labels[i] else 'Cat'}")

    plt.axis('off')
plt.tight_layout()    
plt.show()
